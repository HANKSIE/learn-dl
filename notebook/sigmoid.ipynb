# %%
import matplotlib.pylab as plt
import numpy as np

# %%
x = np.arange(-6, 6, 0.1)

# %%
#sigmoid function
sg = 1 / (1 + np.exp(-x));

# %%
plt.plot(x, sg)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
